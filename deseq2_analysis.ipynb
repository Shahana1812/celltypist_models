# %%
# **DESeq2 Analysis **

# %%
install.packages('IRkernel')
IRkernel::installspec()
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
# Install DESeq2
install.packages("BiocManager")
BiocManager::install("DESeq2")
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.r-project.org
#
# Bioconductor version 3.18 (BiocManager 1.30.22), R 4.3.3 (2024-02-29)
#
# Warning message:
# “package(s) not installed when version(s) same as or greater than current; use
#   `force = TRUE` to re-install: 'DESeq2'”
# Old packages: 'curl', 'dbplyr', 'lava', 'MASS', 'repr', 'rstudioapi',
#   'systemfonts'

# %%
# load libraries
library(DESeq2)
library(tidyverse)
# Out:
# Loading required package: S4Vectors
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# ...

# %%
install.packages("conflicted")
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
library(tidyverse)
conflict_prefer("filter", "dplyr")
conflict_prefer("lag", "dplyr")
conflict_prefer("first", "dplyr")
conflict_prefer("collapse", "dplyr")
conflict_prefer("reduce", "purrr")
conflict_prefer("rename", "dplyr")
conflict_prefer("combined", "dplyr")
conflict_prefer("expand", "tidyr")
conflict_prefer("count", "dplyr")
conflict_prefer("desc", "dplyr")
conflict_prefer("slice", "dplyr")
conflict_prefer("within%()", "lubridate")
conflict_prefer("second()", "lubridate")
conflict_prefer("second<-()", "lubridate")
conflict_prefer("Position()", "ggplot2")
# Out:
# Error in conflict_prefer("filter", "dplyr"): could not find function "conflict_prefer"
# Traceback:

# %%
counts_data <- read.csv('/home/icb/shahana.dilruba/data_extract/metadata.csv')
head(counts_data)
# Out:
#   Unnamed..0                identifier patient   name            barcode_round
# 1 muc21058_AAACCCAAGTTTGAGA muc21058   patient_1 ALI_1_Barcode_1 ALI_1
# 2 muc21058_AAACCCACACGCGCAT muc21058   patient_1 ALI_1_Barcode_1 ALI_1
# 3 muc21058_AAACCCACAGACACAG muc21058   patient_1 ALI_1_Barcode_1 ALI_1
# 4 muc21058_AAACCCAGTATTGCCA muc21058   patient_1 ALI_1_Barcode_1 ALI_1
# 5 muc21058_AAACCCAGTCGTATTG muc21058   patient_1 ALI_1_Barcode_1 ALI_1
# 6 muc21058_AAACCCAGTGCGAACA muc21058   patient_1 ALI_1_Barcode_1 ALI_1
#   sample viral_counts treatment    treatment_virus           infected ⋯
# 1 3      0            TNFa_IFNg    TNFa_IFNg + sars-cov-2    True     ⋯
# 2 3      0            IFNa (b_d)   IFNa (b_d)                False    ⋯
# 3 3      0            IFNg         IFNg                      False    ⋯
# 4 3      0            IFNa (b_d)   IFNa (b_d) + sars-cov-2   True     ⋯
# 5 3      0            Tirapazamine Tirapazamine + sars-cov-2 True     ⋯
# ...

# %%
counts_data
# Out:
#        Unnamed..0                identifier patient   name
# 1      muc21058_AAACCCAAGTTTGAGA muc21058   patient_1 ALI_1_Barcode_1
# 2      muc21058_AAACCCACACGCGCAT muc21058   patient_1 ALI_1_Barcode_1
# 3      muc21058_AAACCCACAGACACAG muc21058   patient_1 ALI_1_Barcode_1
# 4      muc21058_AAACCCAGTATTGCCA muc21058   patient_1 ALI_1_Barcode_1
# 5      muc21058_AAACCCAGTCGTATTG muc21058   patient_1 ALI_1_Barcode_1
# 6      muc21058_AAACCCAGTGCGAACA muc21058   patient_1 ALI_1_Barcode_1
# 7      muc21058_AAACCCATCCAACTGA muc21058   patient_1 ALI_1_Barcode_1
# 8      muc21058_AAACCCATCCGCCTAT muc21058   patient_1 ALI_1_Barcode_1
# 9      muc21058_AAACGAAAGATTGAGT muc21058   patient_1 ALI_1_Barcode_1
# 10     muc21058_AAACGAACAAGTACCT muc21058   patient_1 ALI_1_Barcode_1
# 11     muc21058_AAACGAACACTCTGCT muc21058   patient_1 ALI_1_Barcode_1
# 12     muc21058_AAACGAACATCGCTCT muc21058   patient_1 ALI_1_Barcode_1
# 13     muc21058_AAACGAACATCTGTTT muc21058   patient_1 ALI_1_Barcode_1
# ...

# %%
# read in sample info
colData <- read.csv('/home/icb/shahana.dilruba/data_extract/barcodes.csv')

# %%
colData
# Out:
#        X0
# 1      muc21058_AAACCCAAGTTTGAGA
# 2      muc21058_AAACCCACACGCGCAT
# 3      muc21058_AAACCCACAGACACAG
# 4      muc21058_AAACCCAGTATTGCCA
# 5      muc21058_AAACCCAGTCGTATTG
# 6      muc21058_AAACCCAGTGCGAACA
# 7      muc21058_AAACCCATCCAACTGA
# 8      muc21058_AAACCCATCCGCCTAT
# 9      muc21058_AAACGAAAGATTGAGT
# 10     muc21058_AAACGAACAAGTACCT
# 11     muc21058_AAACGAACACTCTGCT
# 12     muc21058_AAACGAACATCGCTCT
# 13     muc21058_AAACGAACATCTGTTT
# 14     muc21058_AAACGAAGTATTCTCT
# 15     muc21058_AAACGAAGTCATCTAG
# 16     muc21058_AAACGAAGTTATGTCG
# 17     muc21058_AAACGAATCACCCTCA
# 18     muc21058_AAACGAATCGTAGTCA
# 19     muc21058_AAACGAATCTCCTGAC
# 20     muc21058_AAACGCTAGGTACCTT
# 21     muc21058_AAACGCTAGGTCTACT
# 22     muc21058_AAACGCTCACAGCGCT
# 23     muc21058_AAACGCTCACGTACTA
# 24     muc21058_AAACGCTGTGAGTTGG
# 25     muc21058_AAACGCTGTTAAAGTG
# 26     muc21058_AAACGCTTCAAGATAG
# 27     muc21058_AAACGCTTCCTTATCA
# 28     muc21058_AAAGAACCAAGCTGTT
# ...

# %%
# making sure the row names in colData matches to column names in counts_data
all(colnames(colData) %in% rownames(counts_data))
# Out:
# [1] FALSE

# %%
# are they in the same order?
all(colnames(counts_data) == rownames(colData))
# Out:
# Warning message in colnames(counts_data) == rownames(colData):
# “longer object length is not a multiple of shorter object length”
# [1] FALSE
